# %%
import os 
import requests
from googleapiclient.discovery import build
import pprint

# %%
my_api_key = 'AIzaSyAHnp_79CAkg0OfDAVN-K5b0z8o-PVZnD4'
my_cse_id = '012877034587210429365:otvmwnls3yu'

# %%
def google_search(search_term, api_key, cse_id, **kwargs):
    service = build('customsearch', 'v1', developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res['items']

# %%
results = google_search('kiskutyak', my_api_key, my_cse_id, num=20)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-8-24eddfd3608f> in <module>()
# ----> 1 results = google_search('kiskutyak', my_api_key, my_cse_id, num=20)
#
# <ipython-input-4-a6e6ce7fc439> in google_search(search_term, api_key, cse_id, **kwargs)
#       1 def google_search(search_term, api_key, cse_id, **kwargs):
#       2     service = build('customsearch', 'v1', developerKey=api_key)
# ----> 3     res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
#       4     return res['items']
#
# ~/miniconda3/envs/p36/lib/python3.6/site-packages/oauth2client/_helpers.py in positional_wrapper(*args, **kwargs)
#     131                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     132                     logger.warning(message)
# --> 133             return wrapped(*args, **kwargs)
#     134         return positional_wrapper
#     135
#
# ~/miniconda3/envs/p36/lib/python3.6/site-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     842       callback(resp)
#     843     if resp.status >= 300:
# --> 844       raise HttpError(resp, content, uri=self.uri)
#     845     return self.postproc(resp, content)
#     846
#
# HttpError: <HttpError 400 when requesting https://www.googleapis.com/customsearch/v1?q=kiskutyak&cx=012877034587210429365%3Aotvmwnls3yu&num=20&key=AIzaSyAHnp_79CAkg0OfDAVN-K5b0z8o-PVZnD4&alt=json returned "Invalid Value">

# %%
for result in results:
    pprint.pprint(result)
# Out:
# {'cacheId': 'LumIv5jJ0JEJ',
#  'displayLink': 'www.jofogas.hu',
#  'formattedUrl': 'https://www.jofogas.hu/magyarorszag/kutya',
#  'htmlFormattedUrl': 'https://www.jofogas.hu/magyarorszag/kutya',
#  'htmlSnippet': 'Petit basset griffon vendéen <b>kiskutyák</b> eladók ... '
#                 'Fehér puli kan <b>kiskutyák</b> <br>\n'
#                 'törzskönyvvel eladók ... Francia bulldog '
#                 'kölykök,<b>kiskutyák</b>.',
#  'htmlTitle': 'Eladó és ingyen elvihető kutya hirdetések. Apróhirdetések, '
#               'jófogás.hu!',
#  'kind': 'customsearch#result',
#  'link': 'https://www.jofogas.hu/magyarorszag/kutya',
#  'pagemap': {'itemlist': [{'itemlistelement': 'Francia Bulldog Blue&Tan kan 8 '
#                                               '800 Ft Kutya tegnap, 20:48 '
#                                               'Győr-Moson-Sopron, Győr Kedvenc '
#                                               'HIDE'}],
#              'listitem': [{'item': 'Jófogás', 'name': 'Jófogás'},
#                           {'item': 'Összes', 'name': 'Összes'},
#                           {'item': 'Háziállat', 'name': 'Háziállat'},
#                           {'item': 'Kutya', 'name': 'Kutya'}],
#              'metatags': [{'apple-mobile-web-app-status-bar-style': 'yes',
#                            'blocketapp': 'li',
#                            'customtarget': 'dXNlcmRiX2lkPTY5JmNhdGVnb3J5PTQwNjEmemlwY29kZT05MDExJmlzX2JveGVkPTAmZ2FsbGVyeT0xJnBhY2thZ2VfcHJpY2U9ODAwJnVzZXJkYl9pZD00MyZ0aXB1cz0yJm1lZ3llPWd5b3ItbW9zb24tc29wcm9uX21lZ3llJnZldGVsYXI9ODAwCg==',
#                            'format-detection': 'telephone=no',
#                            'google': 'nositelinkssearchbox',
#                            'google-play-app': 'app-id=com.schibsted.iberica.jofogas',
#                            'language': 'Hungarian',
#                            'og:url': 'https://www.jofogas.hu/magyarorszag/kutya',
#                            'position': '0',
#                            'viewport': 'width=1024, initial-scale=0'}]},
#  'snippet': 'Petit basset griffon vendéen kiskutyák eladók ... Fehér puli kan '
#             'kiskutyák \n'
#             'törzskönyvvel eladók ... Francia bulldog kölykök,kiskutyák.',
#  'title': 'Eladó és ingyen elvihető kutya hirdetések. Apróhirdetések, '
#           'jófogás.hu!'}
# {'cacheId': 'RvyDccow9CYJ',
#  'displayLink': 'port.hu',
#  'formattedUrl': 'https://port.hu/adatlap/film/tv/nagypalyas-kiskutyak.../movie-94540',
#  'htmlFormattedUrl': 'https://port.hu/adatlap/film/tv/nagypalyas-<b>kiskutyak</b>.../movie-94540',
#  'htmlSnippet': 'Air Bud öt imádni való kiskutyája, a Pajtik merész dologra '
#                 'vállalkoznak: szüleiket <br>\n'
#                 'kell megmenteniük. Mulatságos és hajmeresztő kalandok várnak '
#                 'rájuk,&nbsp;...',
#  'htmlTitle': 'Nagypályás <b>kiskutyák</b>',
#  'kind': 'customsearch#result',
#  'link': 'https://port.hu/adatlap/film/tv/nagypalyas-kiskutyak-air-buddies/movie-94540',
#  'pagemap': {'aggregaterating': [{'bestrating': '10',
#                                   'ratingcount': '16',
#                                   'ratingvalue': '6',
#                                   'worstrating': '1'}],
#              'cse_image': [{'src': 'https://media.port.hu/images/000/413/173.jpg'}],
#              'cse_thumbnail': [{'height': '181',
#                                 'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRlS2bGhmZ5Zwn5NJWhy23Rul4z74TPMIq0gSEG14YcEdwy7yQkNPTJJdu6',
#                                 'width': '279'}],
#              'hcard': [{'fn': 'Mike Southon'}],
#              'metatags': [{'apple-itunes-app': 'app-id=541579449',
#                            'csrf-param': '_csrf',
#                            'csrf-token': '5LmEqnaB8s2pm8gIlHHJZ2spu8Sg4XbRASaFmaold7StzMfwGu2VmNvcukvkXIE3I22D9pHWDJdzEOqq_EMx4w==',
#                            'google-play-app': 'app-id=com.portdata.tv',
#                            'logcustomtarget': '1',
#                            'msapplication-square150x150logo': '/favicons/windows-tile-150x150.png',
#                            'msapplication-square310x310logo': '/favicons/windows-tile-310x310.png',
#                            'msapplication-square70x70logo': '/favicons/windows-tile-70x70.png',
#                            'msapplication-tilecolor': '#EF3B39',
#                            'msapplication-tileimage': '/favicons/windows-tile-144x144.png',
#                            'og:description': 'Air Bud öt imádni való '
#                                              'kiskutyája, a Pajtik merész '
#                                              'dologra vállalkoznak: szüleiket '
#                                              'kell megmenteniük. Mulatságos és '
#                                              'hajmeresztő kalandok várnak '
#                                              'rájuk, amelyek igazi összetartó '
#                                              'csapatot kovácsolnak a '
#                                              'kiskutyákból, és megmutatják '
#                                              'nekik, milyen is egy igazi '
#                                              'család. Sőt, eközben fény derül '
#                                              'még egy nagy titokra is. A '
#                                              'gyerekek nem kis meglepetésére '
#                                              'kiderül, hogy a kiskutyák tudnak '
#                                              'beszélni.',
#                            'og:image': 'https://media.port.hu/images/000/413/173.jpg',
#                            'og:site_name': 'PORT.hu',
#                            'og:title': 'Nagypályás kiskutyák',
#                            'og:type': 'video.movie',
#                            'og:url': 'https://port.hu/adatlap/film/tv/nagypalyas-kiskutyak-air-buddies/movie-94540',
#                            'title': 'Nagypályás kiskutyák',
#                            'video:actor': 'Slade Pearce',
#                            'video:duration': '80',
#                            'video:release_date': '2006',
#                            'viewport': 'width=device-width, initial-scale=1'}],
#              'movie': [{'countryoforigin': 'amerikai',
#                         'description': 'Air Bud öt imádni való kiskutyája, a '
#                                        'Pajtik merész dologra vállalkoznak: '
#                                        'szüleiket kell megmenteniük. '
#                                        'Mulatságos és hajmeresztő kalandok '
#                                        'várnak rájuk, amelyek igazi '
#                                        'összetartó...',
#                         'duration': 'PT80M',
#                         'genre': 'vígjáték',
#                         'name': 'Nagypályás kiskutyák',
#                         'partofseries': 'Nagypályás kiskutyák'}],
#              'moviereview': [{'best': '10',
#                               'directed_by': 'Robert Vince',
#                               'genre': 'vígjáték',
#                               'name': 'Nagypályás kiskutyák',
#                               'originalrating': '6',
#                               'ratingstars': '3.0',
#                               'runtime': 'PT80M',
#                               'starring': 'Slade Pearce, Patrick Cranshaw, '
#                                           'Trevor Wright',
#                               'summary': 'Air Bud öt imádni való kiskutyája, a '
#                                          'Pajtik merész dologra vállalkoznak: '
#                                          'szüleiket kell megmenteniük. '
#                                          'Mulatságos és hajmeresztő kalandok '
#                                          'várnak...',
#                               'votes': '16'}],
#              'person': [{'name': 'Slade Pearce'},
#                         {'name': 'Patrick Cranshaw'},
#                         {'name': 'Trevor Wright'},
#                         {'name': 'Jane Carr'},
#                         {'name': 'Abigail Breslin'},
#                         {'name': 'Christian Pikes'},
#                         {'name': 'Dominic Scott Kay'},
#                         {'name': 'Tom Everett Scott'},
#                         {'name': 'Karen Holness'},
#                         {'name': 'Kelly Herron'},
#                         {'name': 'Jason Pielak'},
#                         {'name': 'Anna McRoberts'},
#                         {'name': 'Robert Vince'},
#                         {'name': 'Mike Southon'},
#                         {'name': 'Brahm Wenger'},
#                         {'name': 'Robert Vince'},
#                         {'name': 'Anna McRoberts'},
#                         {'name': 'Robert Vince'}]},
#  'snippet': 'Air Bud öt imádni való kiskutyája, a Pajtik merész dologra '
#             'vállalkoznak: szüleiket \n'
#             'kell megmenteniük. Mulatságos és hajmeresztő kalandok várnak '
#             'rájuk,\xa0...',
#  'title': 'Nagypályás kiskutyák'}
# {'cacheId': 'gx7ld4WOjPAJ',
#  'displayLink': 'www.youtube.com',
#  'formattedUrl': 'https://www.youtube.com/watch?v=ZsJBi-649h4',
#  'htmlFormattedUrl': 'https://www.youtube.com/watch?v=ZsJBi-649h4',
#  'htmlSnippet': '2016. jan. 15. <b>...</b> Published on Jan 15, 2016. '
#                 'Category. News &amp; Politics. License. Standard <br>\n'
#                 'YouTube License. Loading... Autoplay When autoplay is '
#                 'enabled,&nbsp;...',
#  'htmlTitle': '<b>Kiskutyák</b> - YouTube',
#  'kind': 'customsearch#result',
#  'link': 'https://www.youtube.com/watch?v=ZsJBi-649h4',
#  'pagemap': {'cse_image': [{'src': 'https://i.ytimg.com/vi/ZsJBi-649h4/hqdefault.jpg'}],
#              'cse_thumbnail': [{'height': '194',
#                                 'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRoV758v_g2G8JaprGneBVKP5f342DCUWvm_YC_qREJCuYFhhRJhWpRqu7b',
#                                 'width': '259'}],
#              'imageobject': [{'height': '360',
#                               'url': 'https://i.ytimg.com/vi/ZsJBi-649h4/hqdefault.jpg',
#                               'width': '480'}],
#              'metatags': [{'al:android:app_name': 'YouTube',
#                            'al:android:package': 'com.google.android.youtube',
#                            'al:android:url': 'vnd.youtube://www.youtube.com/watch?v=ZsJBi-649h4&feature=applinks',
#                            'al:ios:app_name': 'YouTube',
#                            'al:ios:app_store_id': '544007664',
#                            'al:ios:url': 'vnd.youtube://www.youtube.com/watch?v=ZsJBi-649h4&feature=applinks',
#                            'al:web:url': 'https://www.youtube.com/watch?v=ZsJBi-649h4&feature=applinks',
#                            'fb:app_id': '87741124305',
#                            'og:image': 'https://i.ytimg.com/vi/ZsJBi-649h4/hqdefault.jpg',
#                            'og:site_name': 'YouTube',
#                            'og:title': 'Kiskutyák',
#                            'og:type': 'video.other',
#                            'og:url': 'https://www.youtube.com/watch?v=ZsJBi-649h4',
#                            'og:video:height': '360',
#                            'og:video:secure_url': 'https://www.youtube.com/embed/ZsJBi-649h4',
#                            'og:video:type': 'text/html',
#                            'og:video:url': 'https://www.youtube.com/embed/ZsJBi-649h4',
#                            'og:video:width': '640',
#                            'theme-color': '#ff0000',
#                            'title': 'Kiskutyák',
#                            'twitter:app:id:googleplay': 'com.google.android.youtube',
#                            'twitter:app:id:ipad': '544007664',
#                            'twitter:app:id:iphone': '544007664',
#                            'twitter:app:name:googleplay': 'YouTube',
#                            'twitter:app:name:ipad': 'YouTube',
#                            'twitter:app:name:iphone': 'YouTube',
#                            'twitter:app:url:googleplay': 'https://www.youtube.com/watch?v=ZsJBi-649h4',
#                            'twitter:app:url:ipad': 'vnd.youtube://www.youtube.com/watch?v=ZsJBi-649h4&feature=applinks',
#                            'twitter:app:url:iphone': 'vnd.youtube://www.youtube.com/watch?v=ZsJBi-649h4&feature=applinks',
#                            'twitter:card': 'player',
#                            'twitter:image': 'https://i.ytimg.com/vi/ZsJBi-649h4/hqdefault.jpg',
#                            'twitter:player': 'https://www.youtube.com/embed/ZsJBi-649h4',
#                            'twitter:player:height': '360',
#                            'twitter:player:width': '640',
#                            'twitter:site': '@youtube',
#                            'twitter:title': 'Kiskutyák',
#                            'twitter:url': 'https://www.youtube.com/watch?v=ZsJBi-649h4'}],
#              'person': [{'url': 'http://www.youtube.com/channel/UC3-LXRjIgy3fn6n8uyfZq-A'},
#                         {'url': 'https://plus.google.com/103860707420588174491'}],
#              'videoobject': [{'channelid': 'UC3-LXRjIgy3fn6n8uyfZq-A',
#                               'datepublished': '2016-01-15',
#                               'duration': 'PT1M22S',
#                               'embedurl': 'https://www.youtube.com/embed/ZsJBi-649h4',
#                               'genre': 'News & Politics',
#                               'height': '360',
#                               'interactioncount': '31195',
#                               'isfamilyfriendly': 'True',
#                               'name': 'Kiskutyák',
#                               'paid': 'False',
#                               'playertype': 'HTML5 Flash',
#                               'regionsallowed': 'AD,AE,AF,AG,AI,AL,AM,AO,AQ,AR,AS,AT,AU,AW,AX,AZ,BA,BB,BD,BE,BF,BG,BH,BI,BJ,BL,BM,BN,BO,BQ,BR,BS,BT,BV,BW,BY,BZ,CA,CC,CD,CF,CG,CH,CI,CK,CL,CM,CN,CO,CR,CU,CV,CW,CX,CY,CZ,DE,DJ,DK,DM,DO,DZ,EC,EE,EG,EH...',
#                               'thumbnailurl': 'https://i.ytimg.com/vi/ZsJBi-649h4/hqdefault.jpg',
#                               'unlisted': 'False',
#                               'url': 'https://www.youtube.com/watch?v=ZsJBi-649h4',
#                               'videoid': 'ZsJBi-649h4',
#                               'width': '640'}]},
#  'snippet': '2016. jan. 15. ... Published on Jan 15, 2016. Category. News & '
#             'Politics. License. Standard \n'
#             'YouTube License. Loading... Autoplay When autoplay is enabled,\xa0'
#             '...',
#  'title': 'Kiskutyák - YouTube'}
# {'cacheId': 'WUIaKbyUO0UJ',
#  'displayLink': 'www.borsonline.hu',
#  'formattedUrl': 'www.borsonline.hu/aktualis/magyar...a-kiskutyak/145773',
#  'htmlFormattedUrl': 'www.borsonline.hu/aktualis/magyar...a-<b>kiskutyak</b>/145773',
#  'htmlSnippet': '2018. jan. 5. <b>...</b> Hat szállítóbokszban és '
#                 'sporttáskákban csempészett be két magyar férfi 40 <br>\n'
#                 'kiskutyát Németországba. A kölykök még két hónaposak '
#                 'sincsenek,&nbsp;...',
#  'htmlTitle': 'Magyar csempészek: sporttáskákban zötykölődtek a '
#               '<b>kiskutyák</b> ...',
#  'kind': 'customsearch#result',
#  'link': 'http://www.borsonline.hu/aktualis/magyar-csempeszek-sporttaskakban-zotykolodtek-a-kiskutyak/145773',
#  'pagemap': {'cse_image': [{'src': 'http://media.borsonline.hu/cikk/15/149076/big-lead/650x360/1428900_kuty2.jpg'}],
#              'cse_thumbnail': [{'height': '167',
#                                 'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRx_y7AFXBtnMkq3wBYTEk5SWGVE2qKvB2OSY6kbz-HbVww_aqJCPPj3-e1',
#                                 'width': '302'}],
#              'metatags': [{'application-name': 'BorsOnline',
#                            'author': 'BorsOnline',
#                            'copyright': 'Copyright © Lapcom Zrt.',
#                            'doc-type': 'Web Page',
#                            'fb:app_id': '287208751435588',
#                            'fb:pages': '331580946799',
#                            'format-detection': 'telephone=no',
#                            'handheldfriendly': 'true',
#                            'mobileoptimized': '320',
#                            'msapplication-square150x150logo': '/mstile-150x150.png',
#                            'msapplication-square310x310logo': '/mstile-310x310.png',
#                            'msapplication-square70x70logo': '/mstile-70x70.png',
#                            'msapplication-tilecolor': '#FFFFFF',
#                            'msapplication-tileimage': "mstile-144x144.png') }}",
#                            'msapplication-wide310x150logo': '/mstile-310x150.png',
#                            'og:description': 'BorsOnline',
#                            'og:image': 'http://media.borsonline.hu/cikk/15/149076/big-lead/650x360/1428900_kuty2.jpg',
#                            'og:image:height': '360',
#                            'og:image:type': 'image/jpeg',
#                            'og:image:width': '650',
#                            'og:title': 'Magyar csempészek: sporttáskákban '
#                                        'zötykölődtek a kiskutyák',
#                            'og:type': 'article',
#                            'og:url': 'http://www.borsonline.hu/aktualis/magyar-csempeszek-sporttaskakban-zotykolodtek-a-kiskutyak/145773',
#                            'reply-to': 'info@borsonline.hu',
#                            'theme-color': '#8b0203',
#                            'title': 'Magyar csempészek: sporttáskákban '
#                                     'zötykölődtek a kiskutyák | BorsOnline - '
#                                     'Sztárhírek - Pletyka - Krimi - Politika - '
#                                     'Sport',
#                            'viewport': 'width=device-width, initial-scale=1, '
#                                        'maximum-scale=1, user-scalable=no'}]},
#  'snippet': '2018. jan. 5. ... Hat szállítóbokszban és sporttáskákban '
#             'csempészett be két magyar férfi 40 \n'
#             'kiskutyát Németországba. A kölykök még két hónaposak '
#             'sincsenek,\xa0...',
#  'title': 'Magyar csempészek: sporttáskákban zötykölődtek a kiskutyák ...'}
# {'cacheId': 'GRweMgq6BWUJ',
#  'displayLink': 'www.nlcafe.hu',
#  'formattedUrl': 'https://www.nlcafe.hu/.../macska-kutya-elso-talalkozas-tunderi-video/',
#  'htmlFormattedUrl': 'https://www.nlcafe.hu/.../macska-kutya-elso-talalkozas-tunderi-video/',
#  'htmlSnippet': '2016. dec. 3. <b>...</b> Egy videó kedvéért kismacskákat és '
#                 'kiskutyákat ismertettek meg egymással. <br>\n'
#                 'Mindegyik állat eddig csak a testvéreivel találkozott, így '
#                 'az&nbsp;...',
#  'htmlTitle': 'A nap legcukibb videója: <b>kiskutyák</b> és kismacskák első '
#               'találkozása ...',
#  'kind': 'customsearch#result',
#  'link': 'https://www.nlcafe.hu/szabadido/20161203/macska-kutya-elso-talalkozas-tunderi-video/',
#  'pagemap': {'article': [{'image': 'https://nlc.p3k.hu/data/cikk/16/150744/1.jpg'}],
#              'cse_image': [{'src': 'https://nlc.p3k.hu/data/cikk/16/150744/1.jpg'}],
#              'cse_thumbnail': [{'height': '168',
#                                 'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQr1dDJYre3Jo4TBrdh96BHksqEZ7pQta0Li9DAOzh8qwTz08Rt73L7sqNr',
#                                 'width': '300'}],
#              'metatags': [{'application-name': 'NLCafé',
#                            'article:modified_time': '2016-12-03T15:01:52Z',
#                            'article:published_time': '2016-12-03T17:45:00Z',
#                            'article:publisher': 'https://www.facebook.com/noklapjacafe/',
#                            'customtarget': 'dXNlcmRiX2lkPTU4JmF1ZGllbmNlcz0sdHJhdmVsLA==',
#                            'fb:app_id': '512868502061383',
#                            'fb:pages': '1552710344990724',
#                            'og:description': 'Az állatkölykökben elég nagy '
#                                              'cukiságbomba rejlik, de mi '
#                                              'történik akkor, ha többet '
#                                              'eresztünk össze? Mutatjuk!',
#                            'og:image': 'https://nlc.p3k.hu/data/cikk/16/150744/1.jpg',
#                            'og:site_name': 'NLCafé',
#                            'og:title': 'A nap legcukibb videója: kiskutyák és '
#                                        'kismacskák első találkozása',
#                            'og:type': 'article',
#                            'og:url': 'http://www.nlcafe.hu/szabadido/20161203/macska-kutya-elso-talalkozas-tunderi-video/',
#                            'referrer': 'always',
#                            'title': 'A nap legcukibb videója: kiskutyák és '
#                                     'kismacskák első találkozása | NLCafé',
#                            'twitter:card': 'summary',
#                            'twitter:creator': '@zakkantanett',
#                            'twitter:description': 'Az állatkölykökben elég '
#                                                   'nagy cukiságbomba rejlik, '
#                                                   'de mi történik akkor, ha '
#                                                   'többet eresztünk össze? '
#                                                   'Mutatjuk!',
#                            'twitter:domain': 'NLCafé',
#                            'twitter:image': 'https://nlc.p3k.hu/data/cikk/16/150744/1.jpg',
#                            'twitter:site': '@noklapjacafe',
#                            'twitter:title': 'A nap legcukibb videója: '
#                                             'kiskutyák és kismacskák első '
#                                             'találkozása | NLCafé',
#                            'viewport': 'width=device-width, initial-scale=1, '
#                                        'user-scalable=no'}]},
#  'snippet': '2016. dec. 3. ... Egy videó kedvéért kismacskákat és kiskutyákat '
#             'ismertettek meg egymással. \n'
#             'Mindegyik állat eddig csak a testvéreivel találkozott, így az\xa0'
#             '...',
#  'title': 'A nap legcukibb videója: kiskutyák és kismacskák első találkozása '
#           '...'}
# {'cacheId': '4ZUKTyWrj1sJ',
#  'displayLink': 'kiskutya.hu',
#  'formattedUrl': 'kiskutya.hu/elado-kiskutyak/1',
#  'htmlFormattedUrl': 'kiskutya.hu/elado-<b>kiskutyak</b>/1',
#  'htmlSnippet': 'Minőségi sárga Labrador Retriever <b>kiskutyák</b> eladók! '
#                 'Törzskönyvezett, <br>\n'
#                 'egészségügyi szűrésekkel rendelkező szülőktől! Anyuka '
#                 'Romániából származik <br>\n'
#                 'és finn.',
#  'htmlTitle': 'Eladó <b>kiskutyák</b> - 1 | Kiskutya.hu',
#  'kind': 'customsearch#result',
#  'link': 'http://kiskutya.hu/elado-kiskutyak/1',
#  'snippet': 'Minőségi sárga Labrador Retriever kiskutyák eladók! '
#             'Törzskönyvezett, \n'
#             'egészségügyi szűrésekkel rendelkező szülőktől! Anyuka Romániából '
#             'származik \n'
#             'és finn.',
#  'title': 'Eladó kiskutyák - 1 | Kiskutya.hu'}
# {'cacheId': 'VzC2DZRxEaAJ',
#  'displayLink': 'rtl.hu',
#  'formattedUrl': 'rtl.hu/rtlklub/hirek/majdnem-elpusztultak-a-kiskutyak',
#  'htmlFormattedUrl': 'rtl.hu/rtlklub/hirek/majdnem-elpusztultak-a-<b>kiskutyak</b>',
#  'htmlSnippet': '2018. jún. 5. <b>...</b> Majdnem elpusztultak a '
#                 '<b>kiskutyák</b> - gazdájuk egy kocsi felforrósodott <br>\n'
#                 'csomagtartójában, dobozban szállította az állatokat. A hat '
#                 'kölyköt&nbsp;...',
#  'htmlTitle': 'Majdnem elpusztultak a <b>kiskutyák</b> | Híradó',
#  'kind': 'customsearch#result',
#  'link': 'http://rtl.hu/rtlklub/hirek/majdnem-elpusztultak-a-kiskutyak',
#  'pagemap': {'cse_image': [{'src': 'http://cdn6.rtl.hu/e1/d9/majdnem-elpusztultak-a-kiskutyak_image_0516cf99129bcc99f4bd99a8c06c_16-9?size=2'}],
#              'cse_thumbnail': [{'height': '168',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRvsDIhwr1-S9KGPP7y5GQgy6Y8RkFAmaoA5awG9TI_-N7g8qjAvFjWMf4',
#                                 'width': '300'}],
#              'metatags': [{'og:description': 'Kattints még több Híradó '
#                                              'tartalomért!',
#                            'og:image': 'http://cdn6.rtl.hu/e1/d9/majdnem-elpusztultak-a-kiskutyak_image_0516cf99129bcc99f4bd99a8c06c_16-9?size=2',
#                            'og:locale': 'hu_HU',
#                            'og:site_name': 'RTL.hu',
#                            'og:title': 'Majdnem elpusztultak a kiskutyák',
#                            'og:type': 'video',
#                            'og:url': '//rtl.hu/rtlklub/hirek/majdnem-elpusztultak-a-kiskutyak',
#                            'video:duration': '96',
#                            'video:release_date': '2018-06-05 18:40:40',
#                            'video:tag': 'Híradó,belföld,állatkínzás,rtl,kiskutya,forró '
#                                         'csomagtartó',
#                            'viewport': 'width=device-width, '
#                                        'initial-scale=1.0'}]},
#  'snippet': '2018. jún. 5. ... Majdnem elpusztultak a kiskutyák - gazdájuk egy '
#             'kocsi felforrósodott \n'
#             'csomagtartójában, dobozban szállította az állatokat. A hat '
#             'kölyköt\xa0...',
#  'title': 'Majdnem elpusztultak a kiskutyák | Híradó'}
# {'cacheId': 'zi3bks76JPkJ',
#  'displayLink': 'indavideo.hu',
#  'formattedUrl': 'indavideo.hu/video/Nagypalyas_kiskutyak_2006_Teljes_film',
#  'htmlFormattedUrl': 'indavideo.hu/video/Nagypalyas_<b>kiskutyak</b>_2006_Teljes_film',
#  'htmlSnippet': '2017. jan. 17. <b>...</b> VIDEÓ - További teljes online '
#                 'filmek letöltés nélkül, magyarul: http://<br>\n'
#                 'newfilmstreamonline.blogspot.hu/ Nagypályás <b>kiskutyák</b> '
#                 '(2006) Air Buddies&nbsp;...',
#  'htmlTitle': 'Nagypályás <b>kiskutyák</b> (2006) Teljes film - indavideo.hu',
#  'kind': 'customsearch#result',
#  'link': 'http://indavideo.hu/video/Nagypalyas_kiskutyak_2006_Teljes_film',
#  'pagemap': {'cse_image': [{'src': 'https://pics.indavideo.hu/videos/002/391/005/5-3.jpg'}],
#              'cse_thumbnail': [{'height': '275',
#                                 'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTOjl6PtWpiA6xLbYqNzpNjjwfk8VfGnGRhaOK81lOZ_rteXy-tu3j4wKk',
#                                 'width': '183'}],
#              'hcard': [{'fn': 'film',
#                         'nickname': 'film',
#                         'url': 'http://indavideo.hu/profile/blackmoon70/'}],
#              'metatags': [{'author': '//indavideo.hu/profile/blackmoon70/',
#                            'customtarget': 'teljes film,blackmoon70',
#                            'fb:app_id': '154988324573876',
#                            'host': 'ivfr8',
#                            'logcustomtarget': '1',
#                            'medium': 'video',
#                            'msvalidate.01': 'B5290F44A7CF9C4E6346148A4364C6DE',
#                            'og:description': 'További teljes online filmek '
#                                              'letöltés nélkül, magyarul...',
#                            'og:image': 'https://pics.indavideo.hu/videos/002/391/005/5-3.jpg',
#                            'og:image:height': '976',
#                            'og:image:width': '549',
#                            'og:site_name': 'indavideo',
#                            'og:title': 'Nagypályás kiskutyák (2006) Teljes '
#                                        'film',
#                            'og:type': 'article',
#                            'og:url': 'http://indavideo.hu/video/Nagypalyas_kiskutyak_2006_Teljes_film',
#                            'og:video:url': 'http://embed.indavideo.hu/player/video/21219a48af?autostart=1'}],
#              'person': [{'author': 'gyorsfogyastablettaval...',
#                          'name': 'film',
#                          'url': 'gyorsfogyastablettaval...'}]},
#  'snippet': '2017. jan. 17. ... VIDEÓ - További teljes online filmek letöltés '
#             'nélkül, magyarul: http://\n'
#             'newfilmstreamonline.blogspot.hu/ Nagypályás kiskutyák (2006) Air '
#             'Buddies\xa0...',
#  'title': 'Nagypályás kiskutyák (2006) Teljes film - indavideo.hu'}
# {'cacheId': '01Xpn78C8EgJ',
#  'displayLink': 'rtl.hu',
#  'formattedUrl': 'rtl.hu/rtlklub/reggeli/tunderi-kiskutyak-varjak-az-uj-gazdijukat',
#  'htmlFormattedUrl': 'rtl.hu/rtlklub/reggeli/tunderi-<b>kiskutyak</b>-varjak-az-uj-gazdijukat',
#  'htmlSnippet': '2018. jan. 8. <b>...</b> A Heti szőrösben most két édes '
#                 'apróság, Luna és Léna kucorodtak Anna és Miki <br>\n'
#                 'ölébe, sőt a cuki mackók végül Anna ruhája alatt '
#                 'bujkálva&nbsp;...',
#  'htmlTitle': 'Tündéri <b>kiskutyák</b> várják az új gazdijukat | Reggeli',
#  'kind': 'customsearch#result',
#  'link': 'http://rtl.hu/rtlklub/reggeli/tunderi-kiskutyak-varjak-az-uj-gazdijukat',
#  'pagemap': {'cse_image': [{'src': 'http://cdn3.rtl.hu/6a/de/tunderi-kiskutyak-varjak-az-uj-gazdijukat_image_b257dd215e3bd245d8cc73c0d5bc_16-9?size=2'}],
#              'cse_thumbnail': [{'height': '168',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTjutklsQH86RnqVdRmUmkf2X4lC12z3ySDxCcyvGLLYAsqQP6nnIDi9g79',
#                                 'width': '300'}],
#              'metatags': [{'og:description': 'Kattints még több Reggeli '
#                                              'tartalomért!',
#                            'og:image': 'http://cdn3.rtl.hu/6a/de/tunderi-kiskutyak-varjak-az-uj-gazdijukat_image_b257dd215e3bd245d8cc73c0d5bc_16-9?size=2',
#                            'og:locale': 'hu_HU',
#                            'og:site_name': 'RTL.hu',
#                            'og:title': 'Tündéri kiskutyák várják az új '
#                                        'gazdijukat',
#                            'og:type': 'video',
#                            'og:url': '//rtl.hu/rtlklub/reggeli/tunderi-kiskutyak-varjak-az-uj-gazdijukat',
#                            'video:duration': '312',
#                            'video:release_date': '2018-01-08 09:01:23',
#                            'video:tag': 'Reggeli,Heti szőrös,Peller '
#                                         'Anna,Lukács '
#                                         'Miki,gazdi,kutya,kiskutya,kölykök',
#                            'viewport': 'width=device-width, '
#                                        'initial-scale=1.0'}]},
#  'snippet': '2018. jan. 8. ... A Heti szőrösben most két édes apróság, Luna és '
#             'Léna kucorodtak Anna és Miki \n'
#             'ölébe, sőt a cuki mackók végül Anna ruhája alatt bujkálva\xa0...',
#  'title': 'Tündéri kiskutyák várják az új gazdijukat | Reggeli'}
# {'cacheId': 'Q81PubKpsG0J',
#  'displayLink': 'www.blikk.hu',
#  'formattedUrl': 'www.blikk.hu/kiskutyak',
#  'htmlFormattedUrl': 'www.blikk.hu/<b>kiskutyak</b>',
#  'htmlSnippet': '<b>kiskutyák</b> rovat legfrissebb cikkei: Kiskutyákat '
#                 'akartak átcsempészni a határon; <br>\n'
#                 'Fuldokló kiskutyákat mentettek Murvabánya közelében egy '
#                 'autóból a rendőrök;&nbsp;...',
#  'htmlTitle': '<b>kiskutyák</b>',
#  'kind': 'customsearch#result',
#  'link': 'http://www.blikk.hu/kiskutyak',
#  'pagemap': {'cse_image': [{'src': 'http://ocdn.eu/images/pulscms/N2M7MDA_/bb3b19e9bb4625a5abc8effb7b1a4c8a.png'}],
#              'cse_thumbnail': [{'height': '159',
#                                 'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT8lebIR8UYAVmzQ_g-rGTjd5muA8c7xaW-qoCmSWWN9zyQn5vV9TjU13SN',
#                                 'width': '317'}],
#              'metatags': [{'article:published_time': '2018-06-17T10:57:56+01:00',
#                            'dlp:description': 'kiskutyák rovat legfrissebb '
#                                               'cikkei: Kiskutyákat akartak '
#                                               'átcsempészni a határon; '
#                                               'Fuldokló kiskutyákat mentettek '
#                                               'Murvabánya közelében egy '
#                                               'autóból a rendőrök; '
#                                               'Kegyetlenség: Zsákba zárták '
#                                               'őket, majd további kínokat is '
#                                               'át kellett élnie a Felsőzsolcán '
#                                               'kidobott kiskutyáknak; Bíróság '
#                                               'elé állították a győri férfit, '
#                                               'aki kalapáccsal vert agyon '
#                                               'kiskutyákat; Megszólalt a '
#                                               'kutyatenyésztő a Tompa '
#                                               'Eszter-ügyben: "Egy gyilkos '
#                                               'járkált a házunkban";',
#                            'dlp:image': 'http://ocdn.eu/images/pulscms/N2M7MDA_/bb3b19e9bb4625a5abc8effb7b1a4c8a.png',
#                            'dlp:title': 'kiskutyák',
#                            'og:description': 'kiskutyák rovat legfrissebb '
#                                              'cikkei: Kiskutyákat akartak '
#                                              'átcsempészni a határon; Fuldokló '
#                                              'kiskutyákat mentettek Murvabánya '
#                                              'közelében egy autóból a '
#                                              'rendőrök; Kegyetlenség: Zsákba '
#                                              'zárták őket, majd további '
#                                              'kínokat is át kellett élnie a '
#                                              'Felsőzsolcán kidobott '
#                                              'kiskutyáknak; Bíróság elé '
#                                              'állították a győri férfit, aki '
#                                              'kalapáccsal vert agyon '
#                                              'kiskutyákat; Megszólalt a '
#                                              'kutyatenyésztő a Tompa '
#                                              'Eszter-ügyben: "Egy gyilkos '
#                                              'járkált a házunkban";',
#                            'og:image': 'http://ocdn.eu/images/pulscms/N2M7MDA_/bb3b19e9bb4625a5abc8effb7b1a4c8a.png',
#                            'og:image:type': 'image/jpeg',
#                            'og:locale': 'hu_HU',
#                            'og:site_name': 'Blikk.hu',
#                            'og:title': 'kiskutyák',
#                            'og:type': 'article',
#                            'twitter:card': 'photo',
#                            'twitter:image': 'http://ocdn.eu/images/pulscms/N2M7MDA_/bb3b19e9bb4625a5abc8effb7b1a4c8a.png',
#                            'twitter:site': '@blikkhu',
#                            'twitter:title': 'kiskutyák'}]},
#  'snippet': 'kiskutyák rovat legfrissebb cikkei: Kiskutyákat akartak '
#             'átcsempészni a határon; \n'
#             'Fuldokló kiskutyákat mentettek Murvabánya közelében egy autóból a '
#             'rendőrök;\xa0...',
#  'title': 'kiskutyák'}

# %%
len(results)
# Out:
# 10
